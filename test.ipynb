# %%
from genomics.genomics_data import check_variant_in_database
from variantscape.graph_store import G
# Out:
# [variantscape] Loading the network graph...
# [variantscape] Loading the consensus file...

# %%
G.nodes().category()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 G.nodes().category()
#
# AttributeError: 'NodeView' object has no attribute 'category'

# %%
for n in G.nodes:
	if G.nodes[n]['category'] == "Variant":
		print(n)
# Out:
# *1_CYP3A5
# *3_CYP3A5
# 1013dupa_EOGT
# 1016del_BRCA1
# 1017dela_HLA
# 102103ins_PIK3CA
# 1022inst_TP53
# 10351036insct_TP53
# 1035ta_PIK3CA
# 104138del_CDKN2A
# 105ggt_IDH1
# 1100a_HSD3B1
# 1100c_HSD3B1
# 1100del_CHEK2
# 1100delc_CHEK2
# 1100delc_CHK2
# 1110delg_SMARCB1
# 11291130del_MSH6
# 11351139delagaga_MSH6
# 1140dupg_BRCA1
# 1148dela_MSH3
# 1148delc_SMARCB1
# 1153511531delaacag_ETV6
# 1171n_ALK
# 117_NRAS
# 1180delt_TP53
# 118delc_SMAD4
# 1196m_ALK
# 12091210inst_WT1
# 1215delt_ATM
# 12271228dupgg_MUTYH
# 1231g_POLE
# 1245c_HSD3B1
# 1258tc_PIK3CA
# 12612c_KRAS
# 12612s_KRAS
# 1285dupc_FLCN
# 12c_KRAS
# 12d_KRAS
# 12v_HRAS
# 12v_KRAS
# 13571389del_PIK3R1
# 14311433dup_FH
# 1467dela_MLH3
# 146_NRAS
# 1479delag_BRCA1
# 15041508del_BRCA1
# 15121517delggaggg_RET
# 152154del_PTCH1
# 1529delins_BRCA2
# 156157insalu_BRCA2
# 1577dela_PMS2
# 15891591delata_FANCG
# 1592delt_PALB2
# 1593_BRCA1
# 1609ta_ESR1
# 16101613del_MSH6
# 1610ac_ESR1
# 1610ag_ESR1
# 1613ag_ESR1
# 1624ga_PIK3CA
# ...

# %%
check_variant_in_database("BrCA1", "v1534m")
# Out:
# True
