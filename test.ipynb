# %%
from genomics.genomics_data import check_variant_in_database

# %%
check_variant_in_database("BRCA1", "V548E")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 check_variant_in_database("BRCA1", "V548E")
#
# File c:\Users\thiba\Documents\evidence-database\genomics\genomics_data.py:169, in check_variant_in_database(gene_name, variant_name, db_path)
#     158 sql = f"""
#     159     SELECT 1
#     160     FROM   variants  AS v
#    (...)
#     165     LIMIT 1;
#     166 """
#     168 with sqlite3.connect(db_path) as conn:
# --> 169     cursor = conn.execute(sql, (gene_name, variant_name))
#     170     return cursor.fetchone() is not None
#
# OperationalError: near "NOCASE": syntax error
